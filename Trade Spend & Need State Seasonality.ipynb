# %%
pwd
# Out:
# '/Users/tyrachung'

# %%
cd desktop
# Out:
# /Users/tyrachung/Desktop

# %%
import pandas as pd

# %%
df = pd.read_csv('~/Downloads/Cleaned_Total_Trade_Spend.csv')

# %%
#Checking Data
df.head()
# Out:
#    Year  Week    Need State  Amount
# 0  2021     1  Need State 1    5552
# 1  2021     2  Need State 1   18939
# 2  2021     3  Need State 1   11346
# 3  2021     4  Need State 1    4801
# 4  2021     5  Need State 1   17470

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
#Defining Years for Plotting
twenty_two = '2022'
twenty_three = '2023'

# %%
#Sorting needstate 1
ns_1 = 'Need State 1'

# %%
twenty_one = '2021'

# %%
#Need State 1, 2021
ns1_filtered_df_21 = df[(df['Year']== twenty_one) & (df['Need State']== ns_1) ]

# %%
#Need State 1, 2021
sns.lineplot(x='Week', y='Amount', data=ns1_filtered_df_21)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 1, 2022
ns1_filtered_df_22 = df[(df['Year']== twenty_two) & (df['Need State']== ns_1) ]

# %%
#Need State 1, 2022
sns.lineplot(x='Week', y='Amount', data=ns1_filtered_df_22)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 1, 2023
ns1_filtered_df_23 = df[(df['Year']== twenty_three) & (df['Need State']== ns_1) ]

# %%
#Need State 1, 2023
sns.lineplot(x='Week', y='Amount', data=ns1_filtered_df_23)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Sorting Need State 2
ns_2 = 'Need State 2'

# %%
#Need State 2, 2021
ns2_filtered_df_21 = df[(df['Year']== twenty_one) & (df['Need State']== ns_2) ]

# %%
#Need State 2, 2021
sns.lineplot(x='Week', y='Amount', data=ns2_filtered_df_21)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 2, 2022
ns2_filtered_df_22 = df[(df['Year']== twenty_two) & (df['Need State']== ns_2) ]

# %%
#Need State 2, 2022
sns.lineplot(x='Week', y='Amount', data=ns2_filtered_df_22)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 2, 2023
ns2_filtered_df_23 = df[(df['Year']== twenty_three) & (df['Need State']== ns_2) ]

# %%
#Need State 2, 2023
sns.lineplot(x='Week', y='Amount', data=ns2_filtered_df_23)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Sorting Need state 3
ns_3= 'Need State 3'

# %%
#Need State 2, 2021
ns3_filtered_df_21 = df[(df['Year']== twenty_one) & (df['Need State']== ns_3) ]

# %%
sns.lineplot(x='Week', y='Amount', data=ns3_filtered_df_21)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 3, 2022
ns3_filtered_df_22 = df[(df['Year']== twenty_two) & (df['Need State']== ns_3) ]

# %%
#Need State 3, 2022
sns.lineplot(x='Week', y='Amount', data=ns3_filtered_df_22)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 3, 2023
ns3_filtered_df_23 = df[(df['Year']== twenty_three) & (df['Need State']== ns_3) ]

# %%
#Need State 3, 2023
sns.lineplot(x='Week', y='Amount', data=ns3_filtered_df_23)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Sorting Need State 4
ns_4 = 'Need State 4'

# %%
#Need State 4, 2021
ns4_filtered_df_21 = df[(df['Year']== twenty_one) & (df['Need State']== ns_4) ]

# %%
#Need State 4, 2021
sns.lineplot(x='Week', y='Amount', data=ns4_filtered_df_21)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 4, 2022
ns4_filtered_df_22 = df[(df['Year']== twenty_two) & (df['Need State']== ns_4) ]

# %%
#Need State 4, 2022
sns.lineplot(x='Week', y='Amount', data=ns4_filtered_df_22)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 4, 2023
ns4_filtered_df_23 = df[(df['Year']== twenty_three) & (df['Need State']== ns_4) ]

# %%
#Need State 4, 2023
sns.lineplot(x='Week', y='Amount', data=ns4_filtered_df_23)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#sorting Need State 5 
ns_5 = 'Need State 5'

# %%
#Need State 5, 2021
ns5_filtered_df_21 = df[(df['Year']== twenty_one) & (df['Need State']== ns_5) ]

# %%
#Need State 5, 2021
sns.lineplot(x='Week', y='Amount', data=ns5_filtered_df_21)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 5, 2022
ns5_filtered_df_22 = df[(df['Year']== twenty_two) & (df['Need State']== ns_5) ]

# %%
#Need State 5, 2022
sns.lineplot(x='Week', y='Amount', data=ns5_filtered_df_22)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
#Need State 5, 2023
ns5_filtered_df_23 = df[(df['Year']== twenty_three) & (df['Need State']== ns_5) ]

# %%
#Need State 5, 2023
sns.lineplot(x='Week', y='Amount', data=ns5_filtered_df_23)
# Out:
# <Axes: xlabel='Week', ylabel='Amount'>

# %%
pwd
# Out:
# '/Users/tyrachung/Desktop'
