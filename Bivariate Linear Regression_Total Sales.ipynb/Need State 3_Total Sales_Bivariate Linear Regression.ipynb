# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly

# %%
df = pd.read_csv('Data/Total Sales_Need State 3.csv')

# %%
year_2021 = df[(df['Year']==2021)]
sns.lineplot(year_2021, x='Week', y='Amount');

# %%
year_2022 = df[(df['Year']==2022)]
sns.lineplot(year_2022, x='Week', y='Amount');

# %%
year_2023 = df[(df['Year']==2023)]
sns.lineplot(year_2023, x='Week', y='Amount');
